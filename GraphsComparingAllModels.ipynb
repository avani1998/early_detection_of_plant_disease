# %% [markdown]
# We have compared the Best versions from the three Models which we compared (Googlenet InceptionV3, VGG, ResNet) and plotted graphs accordingly.

# %%
import matplotlib.pyplot as plt

GoogleNetInceptionV3 = {
    "loss": [0.2855, 0.1066, 0.0869, 0.0789, 0.0341, 0.0232, 0.0184, 0.0148, 0.012, 0.0092, 0.0083, 0.008, 0.0077, 0.0074, 0.0072, 0.0069, 0.0067, 0.0065, 0.0063, 0.0061],
    "accuracy": [0.9253, 0.9667, 0.9725, 0.9737, 0.989, 0.9934, 0.9958, 0.9972, 0.9983, 0.9987, 0.9991, 0.9992, 0.9993, 0.9994, 0.9994, 0.9995, 0.9995, 0.9996, 0.9996, 0.9996]
}
VGG = {
    "loss": [1.9910, 0.9681, 0.8022, 0.7251, 0.6525, 0.6167, 0.5702, 0.5377, 0.5319, 0.5114, 0.4742, 0.4729, 0.4490, 0.4241, 0.4246, 0.4162, 0.3974, 0.3796, 0.4080, 0.3932],
    "accuracy": [0.4532, 0.6891, 0.7406, 0.7684, 0.7918, 0.8036, 0.8191, 0.8297, 0.8336, 0.8404, 0.8504, 0.8526, 0.8594, 0.8667, 0.8673, 0.8695, 0.8754, 0.8824, 0.8730, 0.8769]
}
ResNet = {
    "loss": [3.2657, 2.9512, 2.7011, 2.4819, 2.3143, 2.1899, 2.0958, 2.0246, 1.9690, 1.9218, 1.8860, 1.8528, 1.8224, 1.8020, 1.7756, 1.7513, 1.7376, 1.7281, 1.7038, 1.6944, 1.6770, 1.6675, 1.6532, 1.6393, 1.6300, 1.6187, 1.6104, 1.5936, 1.5879, 1.5773, 1.5682, 1.5584, 1.5505, 1.5408, 1.5311, 1.5234, 1.5091, 1.5107, 1.5018, 1.4930, 1.4843, 1.4771, 1.4714, 1.4619, 1.4589, 1.4502, 1.4457, 1.4417, 1.4293, 1.4236],
    "accuracy": [0.1670, 0.2224, 0.2684, 0.3205, 0.3588, 0.3861, 0.4055, 0.4198, 0.4314, 0.4427, 0.4463, 0.4578, 0.4606, 0.4672, 0.4768, 0.4823, 0.4875, 0.4883, 0.4965, 0.5002, 0.5037, 0.5062, 0.5105, 0.5141, 0.5181, 0.5191, 0.5216, 0.5274, 0.5294, 0.5331, 0.5358, 0.5404, 0.5407, 0.5443, 0.5459, 0.5471, 0.5510, 0.5513, 0.5511, 0.5566, 0.5598, 0.5618, 0.5644, 0.5652, 0.5664, 0.5663, 0.5689, 0.5686, 0.5735, 0.5781]
}

epochs_range1 = range(1, len(GoogleNetInceptionV3["loss"]) + 1)
epochs_range2 = range(1, len(VGG["loss"]) + 1)
epochs_range3 = range(1, len(ResNet["loss"]) + 1)

plt.figure(figsize=(12, 8))

plt.subplot(1, 2, 1)
plt.plot(epochs_range1, GoogleNetInceptionV3["loss"], label='GoogleNetInceptionV3 Loss')
plt.plot(epochs_range2, VGG["loss"], label='VGG Loss')
plt.plot(epochs_range3, ResNet["loss"], label='ResNet Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Comparison of Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range1, GoogleNetInceptionV3["accuracy"], label='GoogleNetInceptionV3 Accuracy')
plt.plot(epochs_range2, VGG["accuracy"], label='VGG Accuracy')
plt.plot(epochs_range3, ResNet["accuracy"], label='ResNet Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Comparison of Accuracy')

plt.show()
